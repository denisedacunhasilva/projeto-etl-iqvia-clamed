# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.etl import transform as t
from src.etl import extract as e

#try:
    #obter dados 
df = e.extrair_filial_brick_data_xlsx('../data/raw/filial-brick_sample.xlsx')

    #transformar dados
    #df_clean = t.limpar_filial_brick_data_xlsx(df)
#except Exception as ex:
    #print('Erro ao executar extrair dados: ', ex)

# %%
df_clean = t.limpar_filial_brick_data_xlsx(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_clean = t.limpar_filial_brick_data_xlsx(df)
#
# File c:\Users\deni_\projeto-etl-iqvia-clamed\src\etl\transform.py:36, in limpar_filial_brick_data_xlsx(df)
#      33     nome = nome.title()
#      34     return nome
# ---> 36 df_clean['nome'] = df_clean['nome'].apply(limpar_nome)
#      37 df_clean.fillna({'nome': 'Não Informado'}, inplace=True)
#
# NameError: name 'df_clean' is not defined

# %%
#exibir dados
display(df)
# Out:
#                               brick  Cód. Filial
# 0                            1 - SE          402
# 1           92 - CHAC.SANTO ANTONIO          454
# 2                    181 - REGISTRO          423
# 3        257 - S.J.RIO PRETO-CENTRO          394
# 4    271 - S.J.RIO PRETO-V.S.MANOEL          417
# ..                              ...          ...
# 581              1383 - PASSO FUNDO          883
# 582              1383 - PASSO FUNDO          457
# 583              1383 - PASSO FUNDO          503
# 584              1383 - PASSO FUNDO          526
# 585              1383 - PASSO FUNDO          621
#
# [586 rows x 2 columns]
